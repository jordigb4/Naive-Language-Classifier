# %% [markdown]
# # Test

# %%
from language_identifier import LanguageIdentifier
from sklearn.metrics import confusion_matrix, accuracy_score, ConfusionMatrixDisplay
import matplotlib.pyplot as plt

# %%
LangId = LanguageIdentifier(smoothing='Abs_disc')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 LangId = LanguageIdentifier(smoothing='Abs_disc')
#
# File c:\Users\jerez\Documents\4rt_Cuatrimestre\PLH\Lab\Git\Naive-Language-Classifier\language_identifier.py:19, in LanguageIdentifier.__init__(self, smoothing, alpha, delta)
#      16 self.languages = ["deu", "eng", "fra", "ita", "nld", "spa"]
#      17 self.languages_encoding = {"deu" : 0, "eng" : 1, "fra" : 2, "ita" : 3, "nld" : 4, "spa" : 5}
# ---> 19 self.__train()
#
# File c:\Users\jerez\Documents\4rt_Cuatrimestre\PLH\Lab\Git\Naive-Language-Classifier\language_identifier.py:29, in LanguageIdentifier.__train(self)
#      27 for language in self.languages:
#      28     corpora = self.__read_corpora(f"corpora/{language}_trn.txt")
# ---> 29     self.trigrams_corpora[language], self.total_trigrams_corpora[language] = self.__get_trigrams(corpora)
#
# File c:\Users\jerez\Documents\4rt_Cuatrimestre\PLH\Lab\Git\Naive-Language-Classifier\language_identifier.py:45, in LanguageIdentifier.__get_trigrams(self, corpora)
#      43 tr_c = {}
#      44 ct = 0
# ---> 45 self.n1,self.n2 = 0
#      46 for tr, c in finder.ngram_fd.items():
#      47     if c == 1: self.n1 += 1
#
# TypeError: cannot unpack non-iterable int object

# %% [markdown]
# ## METRICS

# %%
deu_pred = LangId.identify_language(f"corpora/deu_tst.txt")
eng_pred = LangId.identify_language(f"corpora/eng_tst.txt")
fra_pred = LangId.identify_language(f"corpora/fra_tst.txt")
ita_pred = LangId.identify_language(f"corpora/ita_tst.txt")
nld_pred = LangId.identify_language(f"corpora/nld_tst.txt")
spa_pred = LangId.identify_language(f"corpora/spa_tst.txt")

# %%
deu_true = np.zeros(deu_pred.shape[0])
eng_true = np.ones(eng_pred.shape[0])
fra_true = np.ones(fra_pred.shape[0])*2
ita_true = np.ones(ita_pred.shape[0])*3
nld_true = np.ones(nld_pred.shape[0])*4
spa_true = np.ones(spa_pred.shape[0])*5

# %%
y_pred = np.concatenate([deu_pred,eng_pred,fra_pred,ita_pred,nld_pred,spa_pred])
y_true = np.concatenate([deu_true,eng_true,fra_true,ita_true,nld_true,spa_true])

# %%
cm = confusion_matrix(y_true,y_pred)
acc = accuracy_score(y_true,y_pred)
acc
# Out:
# 0.9986162746111398

# %%
disp = ConfusionMatrixDisplay(confusion_matrix = cm)
disp.plot()
